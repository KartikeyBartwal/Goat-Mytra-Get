# %%
import numpy as np
import pandas as pd

# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is 6220-5780
#
#  Directory of D:\goat mytra
#
# 16-06-2024  03:09    <DIR>          .
# 16-06-2024  03:09    <DIR>          ..
# 15-06-2024  20:29                 9 .gitignore
# 15-06-2024  20:15    <DIR>          .ipynb_checkpoints
# 15-06-2024  23:32    <DIR>          __pycache__
# 15-06-2024  17:04                 0 data_ingestion.py
# 15-06-2024  19:09                 0 Dockerfile
# 15-06-2024  20:21               673 exceptions.py
# 15-06-2024  23:50            52,546 Experiment Notebook (meat quality) .ipynb
# 16-06-2024  03:09            59,958 Experiment Notebook (milk quality) .ipynb
# 15-06-2024  23:31             3,484 fast_api.py
# 15-06-2024  17:04                 0 feature_engineering.py
# 15-06-2024  22:41             5,369 goat_dataset.csv
# 15-06-2024  20:42               269 goat_inputs.py
# 15-06-2024  20:20               459 logger.py
# 15-06-2024  20:21    <DIR>          logs
# 15-06-2024  19:11                 0 main_pipeline.py
# 15-06-2024  22:57               720 meat_quality_model.pkl
# 16-06-2024  03:09            12,097 milk_quality_model.pkl
# 15-06-2024  19:06                 0 MLflow.py
# 15-06-2024  23:50    <DIR>          mlruns
# 15-06-2024  17:05                 0 model_trainer.py
# 15-06-2024  19:13    <DIR>          myvenv
# 15-06-2024  21:07             4,790 preprocessor.pkl
# 15-06-2024  22:12             3,975 preprocessor_.pkl
# 15-06-2024  20:35               191 requirements.txt
# 16-06-2024  00:40    <DIR>          rust_functions
#               19 File(s)        144,540 bytes
#                8 Dir(s)  972,170,035,200 bytes free

# %%
df = pd.read_csv("goat_dataset.csv")

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.head()
# Out:
#   owner_name  adhaar_number  goat_id  milk_in_litres  age  height  weight  \
# 0      Aarav   123456789012        1              10    2      70      35
# 1     Vihaan   987654321098        2              15    3      75      40
# 2     Vivaan   456123789012        3              20    4      80      45
# 3     Aadhya   321654987012        4               8    1      65      30
# 4      Anaya   654789123456        5              12    5      85      50
#
#   pregnancy    behavior  gender  hay_grass_intake  meat_quality_of_the_goat  \
# 0        no      docile  female                 5                         4
# 1       yes      normal  female                 6                         3
# 2        no  aggressive    male                 7                         5
# 3        no      docile    male                 4                         2
# 4       yes      normal  female                 8                         4
#
#    milk_quality_of_the_goat
# 0                         5
# 1                         4
# 2                         3
# 3                         2
# 4                         5

# %%
df.shape
# Out:
# (90, 13)

# %%
df.describe()
# Out:
#        adhaar_number    goat_id  milk_in_litres        age     height  \
# count   9.000000e+01  90.000000       90.000000  90.000000  90.000000
# mean    5.166191e+11  45.500000       16.055556   3.577778  78.500000
# std     2.969927e+11  26.124701        4.645551   1.437677   7.295142
# min     1.234568e+11   1.000000        8.000000   1.000000  65.000000
# 25%     2.583691e+11  23.250000       12.000000   2.000000  72.000000
# 50%     4.561238e+11  45.500000       16.000000   4.000000  80.000000
# 75%     7.894561e+11  67.750000       19.750000   5.000000  85.000000
# max     9.876543e+11  90.000000       25.000000   6.000000  90.000000
#
#           weight  hay_grass_intake  meat_quality_of_the_goat  \
# count  90.000000         90.000000                 90.000000
# mean   41.944444          6.655556                  3.722222
# std     7.199190          1.515175                  1.081279
# min    30.000000          4.000000                  2.000000
# 25%    36.000000          5.000000                  3.000000
# 50%    42.000000          7.000000                  4.000000
# 75%    48.000000          8.000000                  5.000000
# max    55.000000          9.000000                  5.000000
#
#        milk_quality_of_the_goat
# count                 90.000000
# mean                   3.488889
# std                    1.083528
# min                    2.000000
# 25%                    3.000000
# 50%                    3.000000
# 75%                    4.000000
# max                    5.000000

# %% [markdown]
# ## Feature Engineering

# %%
df.drop(["owner_name" , "adhaar_number" , "goat_id"] , axis = 1 , inplace = True)

# %%
df.shape
# Out:
# (90, 10)

# %%
pregnancy_dict = {
    "no" : 0,
    "yes" : 1
}
df['pregnancy'] = df['pregnancy'].map(pregnancy_dict)

# %%
behavior_dict = {
    "docile" : 0,
    "normal" : 1,
    "aggressive" : 2
}
df['behavior'] = df['behavior'].map(behavior_dict)

# %%
gender_dict = {
    "female" : 0,
    "male" : 1
}
df['gender'] = df['gender'].map(gender_dict)

# %%
# import pandas as pd
# from sklearn.preprocessing import OneHotEncoder, StandardScaler
# from sklearn.compose import ColumnTransformer
# from sklearn.impute import SimpleImputer
# from sklearn.pipeline import Pipeline

# %%
df.columns
# Out:
# Index(['milk_in_litres', 'age', 'height', 'weight', 'pregnancy', 'behavior',
#        'gender', 'hay_grass_intake', 'meat_quality_of_the_goat',
#        'milk_quality_of_the_goat'],
#       dtype='object')

# %%
# numerical_columns = ["milk_in_litres" , "age" , "height" , "weight" , "hay_grass_intake"]
# categorical_columns = ["pregnancy" , "behavior" , "gender"]

# %%
## StandardScaler for numerical columns
## OneHotEncoding for categorical columns

# %%
# numerical_pipeline = Pipeline(
#     steps = [
#         ("imputer" , SimpleImputer(strategy = "median")),
#         ("scaler" , StandardScaler())
#     ]
# )

# categorical_pipeline = Pipeline(
#     steps=[
#         ("imputer" , SimpleImputer(strategy = "most_frequent")),
#         ("one_hot_encoder" , OneHotEncoder()),
#         ("scaler" , StandardScaler(with_mean = False))
#     ]
# )

# preprocessor = ColumnTransformer(
#                 [
#                     ("numerical_pipeline",numerical_pipeline,numerical_columns),
#                     ("categorical_pipeline",categorical_pipeline,categorical_columns)
#                 ]
# )

# %% [markdown]
# ## milk_quality_of_the_cow

# %%
x = df.drop(["meat_quality_of_the_goat" , "milk_quality_of_the_goat"] , axis = 1 )
y = df[["milk_quality_of_the_goat"]]

# %%
from sklearn.model_selection import train_test_split

# Assuming X and y are your features and labels respectively
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print(f"Training set size: {x_train.shape[0]}")
print(f"Test set size: {x_test.shape[0]}")
# Out:
# Training set size: 72
# Test set size: 18

# %%
# x_train = preprocessor.fit_transform(x_train)
# x_test = preprocessor.transform(x_test)

# %%
x_train.shape
# Out:
# (72, 8)

# %%
x_test.shape
# Out:
# (18, 8)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Giving every model a chance along with grid search cv implementation

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\maste\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\maste\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\maste\anaconda3\lib\site-packages (from xgboost) (1.11.4)

# %%
X_train = x_train
X_test = x_test

# %%
# !pip install mlflow
# Out:
# Requirement already satisfied: mlflow in c:\users\maste\anaconda3\lib\site-packages (2.13.2)
# Requirement already satisfied: Flask<4 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (2.2.5)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (1.8.1)
# Requirement already satisfied: cachetools<6,>=5.0.0 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (8.1.3)
# Requirement already satisfied: cloudpickle<4 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (2.2.1)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (6.1.3)
# Requirement already satisfied: entrypoints<1 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (0.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (3.1.37)
# Requirement already satisfied: graphene<4 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (3.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (7.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (3.4.1)
# Requirement already satisfied: matplotlib<4 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (3.8.0)
# Requirement already satisfied: numpy<2 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: opentelemetry-api<3,>=1.0.0 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (1.24.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.0.0 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (1.24.0)
# Requirement already satisfied: packaging<25 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (23.2)
# Requirement already satisfied: pandas<3 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (2.1.4)
# Requirement already satisfied: protobuf<5,>=3.12.0 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (4.25.3)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (14.0.2)
# Requirement already satisfied: pytz<2025 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (2023.3.post1)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (6.0.1)
# Requirement already satisfied: querystring-parser<2 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (2.31.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (1.2.2)
# Requirement already satisfied: scipy<2 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (1.11.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (1.4.41)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (0.5.0)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (3.1.3)
# Requirement already satisfied: waitress<4 in c:\users\maste\anaconda3\lib\site-packages (from mlflow) (3.0.0)
# Requirement already satisfied: Mako in c:\users\maste\anaconda3\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.5)
# Requirement already satisfied: colorama in c:\users\maste\anaconda3\lib\site-packages (from click<9,>=7.0->mlflow) (0.4.6)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\maste\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.0.7)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\maste\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (0.58.0)
# Requirement already satisfied: pywin32>=304 in c:\users\maste\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (305.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\maste\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.2.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\maste\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.0.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\maste\anaconda3\lib\site-packages (from gitpython<4,>=3.1.9->mlflow) (4.0.7)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\maste\anaconda3\lib\site-packages (from graphene<4->mlflow) (3.2.3)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\maste\anaconda3\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: aniso8601<10,>=8 in c:\users\maste\anaconda3\lib\site-packages (from graphene<4->mlflow) (9.0.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\maste\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\maste\anaconda3\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\maste\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\maste\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\maste\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\maste\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\maste\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\maste\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\maste\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\maste\anaconda3\lib\site-packages (from opentelemetry-api<3,>=1.0.0->mlflow) (1.2.14)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in c:\users\maste\anaconda3\lib\site-packages (from opentelemetry-sdk<3,>=1.0.0->mlflow) (0.45b0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\maste\anaconda3\lib\site-packages (from opentelemetry-sdk<3,>=1.0.0->mlflow) (4.11.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\maste\anaconda3\lib\site-packages (from pandas<3->mlflow) (2023.3)
# Requirement already satisfied: six in c:\users\maste\anaconda3\lib\site-packages (from querystring-parser<2->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\maste\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maste\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maste\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2024.2.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\maste\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\maste\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (2.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\maste\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\maste\anaconda3\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.0.0->mlflow) (1.14.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\maste\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow) (4.0.0)

# %%
# !pip install dagshub
# Out:
# Requirement already satisfied: dagshub in c:\users\maste\anaconda3\lib\site-packages (0.3.28)
# Requirement already satisfied: PyYAML>=5 in c:\users\maste\anaconda3\lib\site-packages (from dagshub) (6.0.1)
# Requirement already satisfied: fusepy>=3 in c:\users\maste\anaconda3\lib\site-packages (from dagshub) (3.0.1)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\maste\anaconda3\lib\site-packages (from dagshub) (1.4.4)
# Requirement already satisfied: click>=8.0.4 in c:\users\maste\anaconda3\lib\site-packages (from dagshub) (8.1.3)
# Requirement already satisfied: httpx~=0.23.0 in c:\users\maste\anaconda3\lib\site-packages (from dagshub) (0.23.3)
# Requirement already satisfied: GitPython>=3.1.29 in c:\users\maste\anaconda3\lib\site-packages (from dagshub) (3.1.37)
# Requirement already satisfied: rich~=13.1.0 in c:\users\maste\anaconda3\lib\site-packages (from dagshub) (13.1.0)
# Requirement already satisfied: dacite~=1.6.0 in c:\users\maste\anaconda3\lib\site-packages (from dagshub) (1.6.0)
# Requirement already satisfied: tenacity~=8.2.2 in c:\users\maste\anaconda3\lib\site-packages (from dagshub) (8.2.3)
# Requirement already satisfied: gql[requests] in c:\users\maste\anaconda3\lib\site-packages (from dagshub) (3.5.0)
# Requirement already satisfied: dataclasses-json in c:\users\maste\anaconda3\lib\site-packages (from dagshub) (0.5.14)
# Requirement already satisfied: pandas in c:\users\maste\anaconda3\lib\site-packages (from dagshub) (2.1.4)
# Requirement already satisfied: treelib~=1.6.4 in c:\users\maste\anaconda3\lib\site-packages (from dagshub) (1.6.4)
# Requirement already satisfied: pathvalidate~=3.0.0 in c:\users\maste\anaconda3\lib\site-packages (from dagshub) (3.0.0)
# Requirement already satisfied: python-dateutil in c:\users\maste\anaconda3\lib\site-packages (from dagshub) (2.8.2)
# Requirement already satisfied: boto3 in c:\users\maste\anaconda3\lib\site-packages (from dagshub) (1.34.127)
# Requirement already satisfied: colorama in c:\users\maste\anaconda3\lib\site-packages (from click>=8.0.4->dagshub) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\maste\anaconda3\lib\site-packages (from GitPython>=3.1.29->dagshub) (4.0.7)
# Requirement already satisfied: certifi in c:\users\maste\anaconda3\lib\site-packages (from httpx~=0.23.0->dagshub) (2024.2.2)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in c:\users\maste\anaconda3\lib\site-packages (from httpx~=0.23.0->dagshub) (0.16.3)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\maste\anaconda3\lib\site-packages (from rfc3986[idna2008]<2,>=1.3->httpx~=0.23.0->dagshub) (1.5.0)
# Requirement already satisfied: sniffio in c:\users\maste\anaconda3\lib\site-packages (from httpx~=0.23.0->dagshub) (1.3.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\maste\anaconda3\lib\site-packages (from rich~=13.1.0->dagshub) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\maste\anaconda3\lib\site-packages (from rich~=13.1.0->dagshub) (2.15.1)
# Requirement already satisfied: six in c:\users\maste\anaconda3\lib\site-packages (from treelib~=1.6.4->dagshub) (1.16.0)
# Requirement already satisfied: botocore<1.35.0,>=1.34.127 in c:\users\maste\anaconda3\lib\site-packages (from boto3->dagshub) (1.34.127)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\maste\anaconda3\lib\site-packages (from boto3->dagshub) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\maste\anaconda3\lib\site-packages (from boto3->dagshub) (0.10.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\maste\anaconda3\lib\site-packages (from dataclasses-json->dagshub) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\maste\anaconda3\lib\site-packages (from dataclasses-json->dagshub) (0.9.0)
# Requirement already satisfied: graphql-core<3.3,>=3.2 in c:\users\maste\anaconda3\lib\site-packages (from gql[requests]->dagshub) (3.2.3)
# Requirement already satisfied: yarl<2.0,>=1.6 in c:\users\maste\anaconda3\lib\site-packages (from gql[requests]->dagshub) (1.9.3)
# Requirement already satisfied: backoff<3.0,>=1.11.1 in c:\users\maste\anaconda3\lib\site-packages (from gql[requests]->dagshub) (2.2.1)
# Requirement already satisfied: anyio<5,>=3.0 in c:\users\maste\anaconda3\lib\site-packages (from gql[requests]->dagshub) (3.7.1)
# Requirement already satisfied: requests<3,>=2.26 in c:\users\maste\anaconda3\lib\site-packages (from gql[requests]->dagshub) (2.31.0)
# Requirement already satisfied: requests-toolbelt<2,>=1.0.0 in c:\users\maste\anaconda3\lib\site-packages (from gql[requests]->dagshub) (1.0.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\maste\anaconda3\lib\site-packages (from pandas->dagshub) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\maste\anaconda3\lib\site-packages (from pandas->dagshub) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\maste\anaconda3\lib\site-packages (from pandas->dagshub) (2023.3)
# Requirement already satisfied: idna>=2.8 in c:\users\maste\anaconda3\lib\site-packages (from anyio<5,>=3.0->gql[requests]->dagshub) (3.4)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\maste\anaconda3\lib\site-packages (from botocore<1.35.0,>=1.34.127->boto3->dagshub) (2.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\maste\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.29->dagshub) (4.0.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\maste\anaconda3\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx~=0.23.0->dagshub) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\maste\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->dagshub) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\maste\anaconda3\lib\site-packages (from requests<3,>=2.26->gql[requests]->dagshub) (2.0.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\maste\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->dagshub) (1.0.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\maste\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->dagshub) (4.11.0)
# Requirement already satisfied: multidict>=4.0 in c:\users\maste\anaconda3\lib\site-packages (from yarl<2.0,>=1.6->gql[requests]->dagshub) (6.0.4)

# %%
import dagshub
dagshub.init(repo_owner='KartikeyBartwal', repo_name='my-first-repo', mlflow=True)
# Out:
#                                        ❗❗❗ AUTHORIZATION REQUIRED ❗❗❗
# Open the following link in your browser to authorize the client:
# https://dagshub.com/login/oauth/authorize?state=ad2100f9-0e6e-4ab7-9e63-e3b0a5397c61&client_id=32b60ba385aa7cecf24046d8195a71c07dd345d9657977863b52e7748e0f0f28&middleman_request_id=1e423887fa009929482d817792809c8cdec5798cd6dbc5a6d9ed2fb547ae9b4e
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Initialized MLflow to track repo "KartikeyBartwal/my-first-repo"
# Repository KartikeyBartwal/my-first-repo initialized!

# %%
import mlflow
import mlflow.sklearn
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBRegressor

# Define models
models = {
    "Linear Regression": LinearRegression(),
    "Lasso": Lasso(),
    "Ridge": Ridge(),
    "K-Neighbors Regressor": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "XGBRegressor": XGBRegressor(), 
    "AdaBoost Regressor": AdaBoostRegressor()
}

model_list = []
r2_list = []

# Function to evaluate the model
def evaluate_model(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = mean_squared_error(y_true, y_pred, squared=False)
    r2 = r2_score(y_true, y_pred)
    return mae, rmse, r2

# Start MLflow experiment
mlflow.set_experiment("Model Tracking Experiment")

for i in range(len(list(models))):
    model_name = list(models.keys())[i]
    model = list(models.values())[i]

    with mlflow.start_run(run_name=model_name):
        mlflow.log_param("model_name", model_name)
        mlflow.log_param("model_version", i+1)
        
        model.fit(X_train, y_train)  # Train model

        # Make predictions
        y_train_pred = model.predict(X_train)
        y_test_pred = model.predict(X_test)

        print(y_train_pred)

        # Evaluate Train and Test dataset
        model_train_mae, model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)
        model_test_mae, model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

        print(model_name)
        model_list.append(model_name)

        print('Model performance for Training set')
        print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
        print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
        print("- R2 Score: {:.4f}".format(model_train_r2))

        print('----------------------------------')

        print('Model performance for Test set')
        print("- Root Mean Squared Error: {:.4f}".format(model_test_rmse))
        print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
        print("- R2 Score: {:.4f}".format(model_test_r2))
        r2_list.append(model_test_r2)

        print('='*35)
        print('\n')

        # Log metrics to MLflow
        mlflow.log_metric("train_rmse", model_train_rmse)
        mlflow.log_metric("train_mae", model_train_mae)
        mlflow.log_metric("train_r2", model_train_r2)
        mlflow.log_metric("test_rmse", model_test_rmse)
        mlflow.log_metric("test_mae", model_test_mae)
        mlflow.log_metric("test_r2", model_test_r2)

        # Log the model
        mlflow.sklearn.log_model(model, model_name)
# Out:
# 2024/06/16 05:56:19 INFO mlflow.tracking.fluent: Experiment with name 'Model Tracking Experiment' does not exist. Creating a new experiment.
# [[3.21983802]
#  [3.40174097]
#  [3.11937993]
#  [3.96148418]
#  [3.10797539]
#  [3.48247881]
#  [3.11937993]
#  [3.51812448]
#  [3.21983802]
#  [2.96299958]
#  [3.56587532]
#  [3.14845035]
#  [3.36278295]
#  [3.3453631 ]
#  [3.5340226 ]
#  [3.36278295]
#  [3.65133922]
#  [3.26100333]
#  [3.40174097]
#  [3.51812448]
#  [2.65301967]
#  [3.5340226 ]
#  [2.96299958]
#  [2.98710144]
#  [3.60255468]
#  [3.73473573]
#  [3.1924056 ]
#  [2.65008048]
#  [3.65133922]
#  [3.1924056 ]
#  [2.96299958]
#  [3.5340226 ]
#  [3.66891947]
#  [3.65133922]
#  [3.52596678]
#  [3.65133922]
#  [3.10797539]
#  [2.65301967]
#  [3.21983802]
#  [4.99988653]
#  [3.20381014]
#  [2.98710144]
#  [3.87775384]
#  [3.51812448]
#  [3.73473573]
#  [2.42263217]
#  [3.79332363]
#  [3.66891947]
#  [3.66891947]
#  [3.73473573]
#  [3.52596678]
#  [2.65301967]
#  [3.79332363]
#  [3.40174097]
#  [3.36278295]
#  [3.87775384]
#  [4.99988653]
#  [4.99988653]
#  [3.96148418]
#  [4.81948341]
#  [2.84731144]
#  [3.60255468]
#  [2.84731144]
#  [3.87775384]
#  [3.20381014]
#  [3.51812448]
#  [3.36278295]
#  [3.20381014]
#  [3.11937993]
#  [3.56587532]
#  [4.62572196]
#  [4.81948341]]
# Linear Regression
# Model performance for Training set
# - Root Mean Squared Error: 0.9058
# - Mean Absolute Error: 0.7759
# - R2 Score: 0.2614
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.9201
# - Mean Absolute Error: 0.7502
# - R2 Score: 0.3780
# ===================================
# C:\Users\maste\anaconda3\Lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# [3.48843013 3.49044992 3.48371729 3.4816975  3.47833119 3.49516275
#  3.48371729 3.4870836  3.48843013 3.48641034 3.48506381 3.49044992
#  3.48035097 3.49044992 3.49516275 3.48035097 3.49516275 3.49044992
#  3.49044992 3.4870836  3.48371729 3.49516275 3.48641034 3.4816975
#  3.4870836  3.48506381 3.47833119 3.48035097 3.49516275 3.47833119
#  3.48641034 3.49516275 3.48641034 3.49516275 3.48237076 3.49516275
#  3.47833119 3.48371729 3.48843013 3.49179644 3.48371729 3.4816975
#  3.48035097 3.4870836  3.48506381 3.48506381 3.48035097 3.48641034
#  3.48641034 3.48506381 3.48237076 3.48371729 3.48035097 3.49044992
#  3.48035097 3.48035097 3.49179644 3.49179644 3.4816975  3.48506381
#  3.48843013 3.4870836  3.48843013 3.48035097 3.48371729 3.4870836
#  3.48035097 3.48371729 3.48371729 3.48506381 3.49516275 3.48506381]
# Lasso
# Model performance for Training set
# - Root Mean Squared Error: 1.0534
# - Mean Absolute Error: 0.9293
# - R2 Score: 0.0012
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 1.1679
# - Mean Absolute Error: 1.0532
# - R2 Score: -0.0021
# ===================================
#
#
# [[3.26178917]
#  [3.39305239]
#  [3.13625355]
#  [3.91964954]
#  [3.13375657]
#  [3.55770346]
#  [3.13625355]
#  [3.54509691]
#  [3.26178917]
#  [2.99894067]
#  [3.58234926]
#  [3.15670389]
#  [3.34840694]
#  [3.29036833]
#  [3.50286436]
#  [3.34840694]
#  [3.71526913]
#  [3.3006995 ]
#  [3.39305239]
#  [3.54509691]
#  [2.67469426]
#  [3.50286436]
#  [2.99894067]
#  [3.06378939]
#  [3.62387974]
#  [3.73991493]
#  [3.2125394 ]
#  [2.74897878]
#  [3.71526913]
#  [3.2125394 ]
#  [2.99894067]
#  [3.50286436]
#  [3.58035969]
#  [3.71526913]
#  [3.50438629]
#  [3.71526913]
#  [3.13375657]
#  [2.67469426]
#  [3.26178917]
#  [4.87744497]
#  [3.21503639]
#  [3.06378939]
#  [3.84118743]
#  [3.54509691]
#  [3.73991493]
#  [2.56892344]
#  [3.7624046 ]
#  [3.58035969]
#  [3.58035969]
#  [3.73991493]
#  [3.50438629]
#  [2.67469426]
#  [3.7624046 ]
#  [3.39305239]
#  [3.34840694]
#  [3.84118743]
#  [4.87744497]
#  [4.87744497]
#  [3.91964954]
#  [4.62346517]
#  [2.92667405]
#  [3.62387974]
#  [2.92667405]
#  [3.84118743]
#  [3.21503639]
#  [3.54509691]
#  [3.34840694]
#  [3.21503639]
#  [3.13625355]
#  [3.58234926]
#  [4.57112928]
#  [4.62346517]]
# Ridge
# Model performance for Training set
# - Root Mean Squared Error: 0.9079
# - Mean Absolute Error: 0.7774
# - R2 Score: 0.2581
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.9430
# - Mean Absolute Error: 0.7839
# - R2 Score: 0.3466
# ===================================
#
#
# [[2.4]
#  [2.4]
#  [4.4]
#  [4.2]
#  [2.2]
#  [3.8]
#  [4.4]
#  [3.6]
#  [2.4]
#  [3.2]
#  [3.6]
#  [2.4]
#  [3.4]
#  [2.4]
#  [3.8]
#  [3.4]
#  [3.6]
#  [2.6]
#  [2.4]
#  [3.6]
#  [3. ]
#  [3.8]
#  [3.2]
#  [4. ]
#  [3.4]
#  [3.4]
#  [2.2]
#  [3.6]
#  [3.6]
#  [2.2]
#  [3.2]
#  [3.8]
#  [3.8]
#  [3.6]
#  [3.6]
#  [3.6]
#  [2.2]
#  [3. ]
#  [2.4]
#  [3.8]
#  [4.4]
#  [4. ]
#  [4.2]
#  [3.6]
#  [3.4]
#  [3.6]
#  [3.6]
#  [3.8]
#  [3.8]
#  [3.4]
#  [3.6]
#  [3. ]
#  [3.6]
#  [2.4]
#  [3.4]
#  [4.2]
#  [3.8]
#  [3.8]
#  [4.2]
#  [4.4]
#  [3.4]
#  [3.4]
#  [3.4]
#  [4.2]
#  [4.4]
#  [3.6]
#  [3.4]
#  [4.4]
#  [4.4]
#  [3.6]
#  [3.8]
#  [4.4]]
# K-Neighbors Regressor
# Model performance for Training set
# - Root Mean Squared Error: 0.7047
# - Mean Absolute Error: 0.6111
# - R2 Score: 0.5529
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.7958
# - Mean Absolute Error: 0.7000
# - R2 Score: 0.5347
# ===================================
#
#
# [2.         2.         4.66666667 5.         2.         2.
#  4.66666667 3.75       2.         3.33333333 4.         3.
#  3.         3.         4.         3.         4.         3.
#  2.         3.75       2.         4.         3.33333333 4.
#  3.         3.         2.         2.         4.         2.
#  3.33333333 4.         5.         4.         3.         4.
#  2.         2.         2.         5.         4.         4.
#  5.         3.75       3.         4.         3.         5.
#  5.         3.         3.         2.         3.         2.
#  3.         5.         5.         5.         5.         4.
#  3.         3.         3.         5.         4.         3.75
#  3.         4.         4.66666667 4.         5.         4.        ]
# Decision Tree
# Model performance for Training set
# - Root Mean Squared Error: 0.2907
# - Mean Absolute Error: 0.1042
# - R2 Score: 0.9239
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.0786
# - Mean Absolute Error: 0.0185
# - R2 Score: 0.9955
# ===================================
# C:\Users\maste\AppData\Local\Temp\ipykernel_8376\827586874.py:45: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)  # Train model
# [2.05       2.02       4.58266667 4.91666667 2.05       2.67
#  4.58266667 3.72881349 2.05       3.34166667 3.91       2.67
#  2.97       2.96       3.985      2.97       4.00333333 3.42
#  2.02       3.72881349 2.06       3.985      3.34166667 3.87966667
#  3.09771429 3.048      2.01       2.44       4.00333333 2.01
#  3.34166667 3.985      4.89       4.00333333 3.07       4.00333333
#  2.05       2.06       2.05       4.99       4.00916667 3.87966667
#  4.88       3.72881349 3.048      3.64       3.24       4.89
#  4.89       3.048      3.07       2.06       3.24       2.02
#  2.97       4.88       4.99       4.99       4.91666667 4.01
#  3.06       3.09771429 3.06       4.88       4.00916667 3.72881349
#  2.97       4.00916667 4.58266667 3.91       4.05       4.01      ]
# Random Forest Regressor
# Model performance for Training set
# - Root Mean Squared Error: 0.3415
# - Mean Absolute Error: 0.1904
# - R2 Score: 0.8951
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.2549
# - Mean Absolute Error: 0.1710
# - R2 Score: 0.9523
# ===================================
#
#
# [2.0000017 1.9999473 4.6663003 4.99904   2.0003154 2.003757  4.6663003
#  3.7495708 2.0000017 3.333157  3.9995754 2.9971035 2.9999423 3.0021122
#  3.9996748 2.9999423 3.999951  3.0014243 1.9999473 3.7495708 2.0001683
#  3.9996748 3.333157  4.000126  3.0012546 3.0006027 2.0003154 2.0026336
#  3.999951  2.0003154 3.333157  3.9996748 5.00006   3.999951  3.000268
#  3.999951  2.0003154 2.0001683 2.0000017 4.999756  4.000235  4.000126
#  4.999544  3.7495708 3.0006027 3.9971175 3.0004296 5.00006   5.00006
#  3.0006027 3.000268  2.0001683 3.0004296 1.9999473 2.9999423 4.999544
#  4.999756  4.999756  4.99904   4.0001016 3.0000057 3.0012546 3.0000057
#  4.999544  4.000235  3.7495708 2.9999423 4.000235  4.6663003 3.9995754
#  4.996776  4.0001016]
# XGBRegressor
# Model performance for Training set
# - Root Mean Squared Error: 0.2907
# - Mean Absolute Error: 0.1047
# - R2 Score: 0.9239
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.0967
# - Mean Absolute Error: 0.0330
# - R2 Score: 0.9931
# ===================================
# C:\Users\maste\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [2.75       2.75       4.26923077 4.64285714 2.33333333 2.88235294
#  4.26923077 3.33333333 2.75       2.96153846 3.65789474 2.75
#  2.91666667 2.90909091 3.2        2.91666667 4.1        3.
#  2.75       3.33333333 2.85185185 3.2        2.96153846 4.125
#  3.38888889 3.65789474 2.33333333 2.6        4.1        2.33333333
#  2.96153846 3.2        4.6        4.1        3.02380952 4.1
#  2.33333333 2.85185185 2.75       4.8        4.26923077 4.125
#  4.39130435 3.33333333 3.65789474 3.2        3.76923077 4.6
#  4.6        3.65789474 3.02380952 2.85185185 3.76923077 2.75
#  2.91666667 4.39130435 4.8        4.8        4.64285714 3.66666667
#  3.         3.38888889 3.         4.39130435 4.26923077 3.33333333
#  2.91666667 4.26923077 4.26923077 3.65789474 4.1        3.66666667]
# AdaBoost Regressor
# Model performance for Training set
# - Root Mean Squared Error: 0.5745
# - Mean Absolute Error: 0.4859
# - R2 Score: 0.7029
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.5574
# - Mean Absolute Error: 0.4811
# - R2 Score: 0.7717
# ===================================

# %%
pd.DataFrame(list(zip(model_list, r2_list)), columns=['Model Name', 'R2_Score']).sort_values(by=["R2_Score"],ascending=False)
# Out:
#                 Model Name  R2_Score
# 4            Decision Tree  0.995465
# 6             XGBRegressor  0.993127
# 5  Random Forest Regressor  0.952265
# 7       AdaBoost Regressor  0.771747
# 3    K-Neighbors Regressor  0.534694
# 0        Linear Regression  0.377955
# 2                    Ridge  0.346627
# 1                    Lasso -0.002136

# %% [markdown]
# ## KNN Performs the Best

# %%
    model = KNeighborsRegressor(n_neighbors=5)
    model.fit(X_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    print(y_train_pred)
    
    # Evaluate Train and Test dataset
    model_train_mae , model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)

    model_test_mae , model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

    
    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
    print("- R2 Score: {:.4f}".format(model_train_r2))
# Out:
# [[2.4]
#  [2.4]
#  [4.4]
#  [4.2]
#  [2.2]
#  [3.8]
#  [4.4]
#  [3.6]
#  [2.4]
#  [3.2]
#  [3.6]
#  [2.4]
#  [3.4]
#  [2.4]
#  [3.8]
#  [3.4]
#  [3.6]
#  [2.6]
#  [2.4]
#  [3.6]
#  [3. ]
#  [3.8]
#  [3.2]
#  [4. ]
#  [3.4]
#  [3.4]
#  [2.2]
#  [3.6]
#  [3.6]
#  [2.2]
#  [3.2]
#  [3.8]
#  [3.8]
#  [3.6]
#  [3.6]
#  [3.6]
#  [2.2]
#  [3. ]
#  [2.4]
#  [3.8]
#  [4.4]
#  [4. ]
#  [4.2]
#  [3.6]
#  [3.4]
#  [3.6]
#  [3.6]
#  [3.8]
#  [3.8]
#  [3.4]
#  [3.6]
#  [3. ]
#  [3.6]
#  [2.4]
#  [3.4]
#  [4.2]
#  [3.8]
#  [3.8]
#  [4.2]
#  [4.4]
#  [3.4]
#  [3.4]
#  [3.4]
#  [4.2]
#  [4.4]
#  [3.6]
#  [3.4]
#  [4.4]
#  [4.4]
#  [3.6]
#  [3.8]
#  [4.4]]
# AdaBoost Regressor
# Model performance for Training set
# - Root Mean Squared Error: 0.7047
# - Mean Absolute Error: 0.6111
# - R2 Score: 0.5529

# %%
    # model = LinearRegression()
    # model.fit(X_train, y_train) # Train model

    # # Make predictions
    # y_train_pred = model.predict(X_train)
    # y_test_pred = model.predict(X_test)

    # print(y_train_pred)
    
    # # Evaluate Train and Test dataset
    # model_train_mae , model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)

    # model_test_mae , model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

    
    # print(list(models.keys())[i])
    # model_list.append(list(models.keys())[i])
    
    # print('Model performance for Training set')
    # print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
    # print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
    # print("- R2 Score: {:.4f}".format(model_train_r2))

# %%
import pickle

# %%
with open('milk_quality_model.pkl', 'wb') as file:
    pickle.dump(model, file)
